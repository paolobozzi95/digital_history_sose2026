# %% [markdown]
# Basic Python

# %%
print("hello world")

x = 3

y = 5

output = x + y
print(output)

print("output" * 3)
# Out:
# hello world
# 8
# outputoutputoutput

# %%
number_of_students = 10

number = 3.5676

is_thursday = True

our_string = "digital history 2026"

long_string = """
Hello, welcome to digital history
This is a long string that spans multiple lines.
You can include line breaks and indentation as needed.

"""

type(number_of_students)

print(type(number_of_students))
print(type(number)) 
print(type(is_thursday))
print(type(our_string))

print(long_string)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
#
# Hello, welcome to digital history
# This is a long string that spans multiple lines.
# You can include line breaks and indentation as needed.
