# %% [markdown]
# I want to remove all the punctuation signs from the text we elaborated for the homework

# %%
#import file der_prozess.txt

with open('der_prozess.txt', 'r') as file:
    prozess = file.read()

print(prozess)

tokenised = prozess.split()
print(type(tokenised))

#for every word in tokenised, write it in caps lock
for word in tokenised: 
    print(word.upper())
# Out:
# Jemand musste Josef K. verleumdet haben,
# denn ohne dass er etwas Böses getan hätte,
# wurde er eines Morgens verhaftet.
# Die Köchin der Frau Grubach,
# seiner Zimmervermieterin,
# die ihm jeden Tag gegen acht Uhr früh das Frühstück brachte,
# kam diesmal nicht.
# <class 'list'>
# JEMAND
# MUSSTE
# JOSEF
# K.
# VERLEUMDET
# HABEN,
# DENN
# OHNE
# DASS
# ER
# ETWAS
# BÖSES
# GETAN
# HÄTTE,
# WURDE
# ER
# EINES
# MORGENS
# VERHAFTET.
# DIE
# KÖCHIN
# DER
# FRAU
# GRUBACH,
# SEINER
# ZIMMERVERMIETERIN,
# DIE
# IHM
# JEDEN
# TAG
# GEGEN
# ACHT
# UHR
# FRÜH
# DAS
# FRÜHSTÜCK
# BRACHTE,
# KAM
# DIESMAL
# NICHT.

# %%
 #if : I want to write a script with if

my_string = []

for word in tokenised:
    if word == "Josef": 
        my_string.append(word.upper())
    else:
        my_string.append(word)

print(my_string)
# Out:
# ['Jemand', 'musste', 'JOSEF', 'K.', 'verleumdet', 'haben,', 'denn', 'ohne', 'dass', 'er', 'etwas', 'Böses', 'getan', 'hätte,', 'wurde', 'er', 'eines', 'Morgens', 'verhaftet.', 'Die', 'Köchin', 'der', 'Frau', 'Grubach,', 'seiner', 'Zimmervermieterin,', 'die', 'ihm', 'jeden', 'Tag', 'gegen', 'acht', 'Uhr', 'früh', 'das', 'Frühstück', 'brachte,', 'kam', 'diesmal', 'nicht.']

# %%
#while

#print the first 10 words

i = 0
while i < 10:
    print(tokenised[i])
    i += 1   #i = i + 1
# Out:
# Jemand
# Josef
# verleumdet
# denn
# dass

# %%
#I want to create a dictionary
# {}

paolos_dictionary = {
    "name" : "Paolo",
    "age" : 30,
    "study" : {"BA" : "Pisa",
               "Erasmus" : "Sheffield",
               "PhD" : "Berlin"}
}

#print the name of the university where Paolo did his Erasmus
print(paolos_dictionary["study"]["BA"])

print(f"Paolo did his studies in {paolos_dictionary['study']['BA']}")
# Out:
# Pisa
# Paolo did his studies in Pisa
